# %% [markdown]
# # Minería de Datos - Clase 1
#
# ## Descripción
# En esta notebook se desarrollan los ejercicios correspondientes a la clase 1 de Minería de Datos.
# Se trabajan conceptos básicos como datos, información y conocimiento, junto con los procesos KDD y CRISP-DM,
# problemas comunes en los datos y un ejercicio integrador aplicado a un caso práctico.
#
# ## Índice
#
# 1. Conceptos básicos: datos, información y conocimiento
# 2. Proceso KDD y modelo CRISP-DM
# 3. Detección de problemas en datos y visualización
# 4. Ejercicio integrador (análisis de clientes)

# %% [markdown]
# ## Ejercicio: Datos, Información y Conocimiento
#
# ### Caso del banco
# - Dato: 10.000 transacciones en 24 horas.
# - Información: 2.000 provienen de cuentas nuevas y países inusuales.
# - Conocimiento: esas transacciones tienen alta probabilidad de fraude, por eso se activa una alerta.
# - Minería de datos: detecta patrones anómalos.
#
# ### Caso de la tienda online
# - Dato: registros de compras.
# - Información: 70% de los que compran laptops también compran fundas.
# - Conocimiento: ofrecer descuentos en fundas puede aumentar ventas.
# - Minería de datos: encuentra relaciones entre productos.
#
# ### Caso del hospital
# - Dato: registros de pacientes.
# - Información: personas con hipertensión tienen 40% más riesgo cardíaco.
# - Conocimiento: implementar controles preventivos.
# - Minería de datos: identifica patrones de riesgo.

# %% [markdown]
# ## Ejercicio: Proceso KDD y CRISP-DM
#
# ### Ejercicio 1: Identificación de fases del proceso KDD
#
# Se presentan las siguientes situaciones:
#
# 1. Un equipo descarga una base de datos de ventas de un supermercado.
# → Corresponde a la fase de **Selección**, ya que se eligen los datos con los que se va a trabajar.
#
# 2. Se eliminan datos faltantes y se corrigen errores.
# → Es **Preprocesamiento**, porque se están limpiando los datos para evitar problemas en el análisis.
#
# 3. Se aplica un algoritmo de clustering para segmentar clientes.
# → Es **Minería de Datos**, ya que se están aplicando técnicas para descubrir patrones.
#
# 4. Se analizan los resultados obtenidos.
# → Corresponde a **Evaluación**, porque se interpretan los resultados para ver si son útiles.
#
# ---
#
# ### Ejercicio 2: Aplicación del modelo CRISP-DM
#
# Un banco quiere detectar fraudes y realiza las siguientes acciones:
#
# 1. Se analizan fraudes anteriores y se define el objetivo.
# → **Comprensión del negocio**, porque se busca entender el problema y qué se quiere lograr.
#
# 2. Se limpian y transforman los datos.
# → **Preparación de los datos**, ya que se dejan listos para el análisis.
#
# 3. Se prueban modelos de Machine Learning.
# → **Modelado**, porque se aplican técnicas para encontrar patrones.
#
# 4. Se evalúa cuál modelo funciona mejor.
# → **Evaluación**, donde se analiza el rendimiento de los modelos.
#
# 5. Se implementa un sistema automático.
# → **Despliegue**, ya que el modelo se pone en uso real.

# %% [markdown]
# ## Ejercicio: Detección de problemas y análisis de datos
#
# ### Ejercicio 1: Detección de problemas en datos
#
# Se tiene el siguiente conjunto de datos:
#
# | Nombre | Edad | Nota |
# |--------|------|------|
# | Juan   | 22   | 8    |
# | Sofía  | -3   | 10   |
# | Lucas  | 25   | 6    |
# | Ana    | 20   | None |
# | Marcos | 21   | 4    |
#
# Análisis:
#
# - Hay un valor inválido en la edad (Sofía tiene -3).
# - Falta una nota (valor nulo en Ana).
#
# Posibles soluciones:
#
# - Corregir o eliminar el valor negativo de edad.
# - Reemplazar la nota faltante (por ejemplo, con el promedio) o eliminar el registro si afecta el análisis.
#
# Transformación:
#
# - Se podría normalizar la edad o las notas para compararlas mejor.
# - También convertir los datos a formato numérico limpio antes de analizarlos.
#
# ---
#
# ### Ejercicio 2: Creación de gráficos en Python
#
# Datos:
#
# | Producto | Precio | Cantidad_Vendida |
# |----------|--------|------------------|
# | A        | 10     | 50               |
# | B        | 20     | 30               |
# | C        | 15     | 40               |
# | D        | 25     | 20               |

# %%
import pandas as pd
import matplotlib.pyplot as plt

datos = {
    "Producto": ["A", "B", "C", "D"],
    "Precio": [10, 20, 15, 25],
    "Cantidad_Vendida": [50, 30, 40, 20]
}

df = pd.DataFrame(datos)

# Gráfico de barras de precios
plt.bar(df["Producto"], df["Precio"])
plt.xlabel("Producto")
plt.ylabel("Precio")
plt.title("Precio por producto")
plt.show()

# Gráfico de líneas de cantidad vendida
plt.plot(df["Producto"], df["Cantidad_Vendida"], marker="o")
plt.xlabel("Producto")
plt.ylabel("Cantidad Vendida")
plt.title("Cantidad vendida por producto")
plt.grid(True)
plt.show()

# %% [markdown]
# Interpretación:
#
# El gráfico de precios muestra que el producto D es el más caro, mientras que el producto A tiene el menor precio. Por otro lado, en el gráfico de cantidad vendida se observa que el producto A es el más vendido y el producto D el menos demandado.
#
# En conjunto, se puede notar una tendencia inversa entre precio y cantidad vendida: los productos más económicos tienden a venderse más, mientras que los más caros presentan menor volumen de ventas.

# %% [markdown]
# ## Ejercicio Integrador: Análisis de clientes (Telecomunicaciones)
#
# ### 1. Aplicación de KDD y CRISP-DM
#
# Proceso KDD:
#
# - Selección: tomar los datos de clientes (edad, plan, consumo, reclamos, estado).
# - Preprocesamiento: verificar errores, valores faltantes o inconsistentes.
# - Transformación: convertir variables categóricas como "Plan" y "Estado_Cuenta" a valores numéricos si es necesario.
# - Minería de datos: buscar patrones, por ejemplo clientes morosos o con alto consumo.
# - Evaluación: analizar si los patrones encontrados sirven para tomar decisiones.
#
# CRISP-DM:
#
# - Comprensión del negocio: detectar clientes con riesgo de mora o baja.
# - Comprensión de los datos: revisar qué información tenemos disponible.
# - Preparación: limpiar y transformar los datos.
# - Modelado: aplicar técnicas para encontrar patrones.
# - Evaluación: validar si los resultados son útiles.
# - Despliegue: usar los resultados para tomar decisiones (ej: retener clientes).
#
# ---
#
# ### 2. Preprocesamiento de datos
#
# Posibles problemas:
#
# - No hay valores faltantes en el ejemplo, pero podría haberlos en datos reales.
# - Variables categóricas (Plan, Estado_Cuenta) necesitan transformarse.
#
# Tratamiento:
#
# - Codificar variables categóricas (ej: Básico=0, Premium=1, etc).
# - Verificar que no haya datos fuera de rango.

# %%
import pandas as pd

datos = {
    "Cliente": [1, 2, 3, 4, 5],
    "Edad": [25, 40, 32, 22, 35],
    "Plan": ["Básico", "Premium", "Estándar", "Básico", "Premium"],
    "Consumo_GB": [5, 50, 10, 7, 45],
    "Reclamos": [1, 0, 2, 3, 0],
    "Estado_Cuenta": ["Pagado", "Pagado", "Moroso", "Moroso", "Pagado"]
}

df = pd.DataFrame(datos)
df
# Out:
#    Cliente  Edad      Plan  Consumo_GB  Reclamos Estado_Cuenta
# 0        1    25    Básico           5         1        Pagado
# 1        2    40   Premium          50         0        Pagado
# 2        3    32  Estándar          10         2        Moroso
# 3        4    22    Básico           7         3        Moroso
# 4        5    35   Premium          45         0        Pagado

# %%
valores_faltantes = df.isnull().sum().sum()
duplicados = df.duplicated().sum()

print("Valores faltantes:", valores_faltantes)
print("Registros duplicados:", duplicados)
# Out:
# Valores faltantes: 0
# Registros duplicados: 0

# %% [markdown]
# Al revisar el conjunto de datos no se observan valores faltantes ni registros duplicados.
# Esto permite trabajar el análisis de forma directa, aunque en un caso real igualmente sería necesario revisar inconsistencias o valores fuera de rango.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Histograma de consumo
sns.histplot(df["Consumo_GB"], bins=5, kde=True)
plt.title("Distribución del consumo de datos")
plt.xlabel("Consumo_GB")
plt.ylabel("Frecuencia")
plt.show()

# Estado de cuenta
sns.countplot(x=df["Estado_Cuenta"])
plt.title("Cantidad de clientes según estado de cuenta")
plt.xlabel("Estado de cuenta")
plt.ylabel("Cantidad")
plt.show()

# %% [markdown]
# ## Interpretación de resultados
# Se observa que la mayoría de los clientes se encuentran en estado "Pagado". En cuanto al consumo, los valores más altos corresponden a clientes con cuentas al día, mientras que los clientes morosos presentan consumos más bajos.
#
# Sin embargo, debido al tamaño reducido del conjunto de datos, no es posible establecer conclusiones definitivas, aunque se pueden identificar posibles tendencias.
#
# Conclusión: Estos resultados permiten una primera aproximación para identificar patrones, que podrían ser útiles en análisis más amplios para detectar clientes en riesgo.
